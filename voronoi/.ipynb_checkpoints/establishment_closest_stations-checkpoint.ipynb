# %%
import numpy as np
import pandas as pd
import os.path

DSET_ROOT = "/Users/ever/Documents/HackathononKIBots/WorkTeam1/datasets/"
#DSET_ROOT = "https://raw.githubusercontent.com/gywn/WorkTeam1/master/datasets/all_nodes.json"



def load_est_data(est_data_path = DSET_ROOT):
    json_path=os.path.join(est_data_path,"all_nodes.json")
    return pd.read_json(json_path)
def load_station_data(est_data_path = DSET_ROOT):
    json_path=os.path.join(est_data_path,"haltestellen.json")
    return pd.read_json(json_path)
establishments = load_est_data()
stations = load_station_data() 
stations = stations.transpose()
stations = stations.reset_index(drop=True)
stations["lat"]=""
stations["lon"]=""

# %%
statios = stations.sort_values('id')
stations
# Out:
#        id                   name  \
# 0    1023            Forstquelle
# 1    1033     Zgh. Altes Rathaus
# 2    1062         Gutleuthofhang
# 3    1067      St.-Martin-Straße
# 4    1079              Im Hofert
# 5    1081     Redtenbacherstraße
# 6    1084             Sportplatz
# 7    1086         Bärenbach Nord
# 8    1088               Im Anger
# 9    1091          Bärenbach Süd
# 10   1093          Gutleuthofweg
# 11   1094                   HITS
# 12   1102          Villa Schmeil
# 13   1104              Hirtenaue
# 14   1106      Schleifengrundweg
# 15   1107       Hirtenbrunnenweg
# 16   1108        Am Bächenbuckel
# 17   1109        Moselbrunnenweg
# 18   1116             Klingenweg
# 19   1117       Karl-Christ-Str.
# 20   1119        Neckarmünzplatz
# 21   1120          Am Götzenberg
# 22   1121            Boxbergring
# 23   1122            Buchwaldweg
# 24   1123           Fernheizwerk
# 25   1124           Haselnussweg
# 26   1125            Im Eichwald
# 27   1126   Louise-Ebert-Zentrum
# 28   1127    Emmertsgrund Endst.
# 29   1128                  Forum
# ..    ...                    ...
# 901   695            Jakobsgasse
# 902  6957            Untere Rödt
# 903  6959          Im Bosseldorn
# 904   696       Kirchheimer Str.
# 905   697      Eppelheim Rathaus
# 906  7078              Hildastr.
# 907  7097      Hugo-Stotz-Straße
# 908  7135            Speyererhof
# 909  7140        Großsachsen Süd
# 910  7303          Kolpingstraße
# 911  7520              Walzmühle
# 912  7521         Rheinallee Süd
# 913  7522             Drehbrücke
# 914  7526        Rheinallee Nord
# 915   771        FT Hauptbahnhof
# 916   778      FT Feierabendhaus
# 917   806         FT Wormser Tor
# 918  8126                 Schöps
# 919  8143                BH Möhl
# 920  8153   Integr. Gesamtschule
# 921  8154       Ruchheim Schloss
# 922   823        FT Schmiedgasse
# 923   829             Lutherstr.
# 924  8506          Im Heimgarten
# 925  8509        Wendestelle Hbw
# 926  8518  Moll-Gym. 1/Belchens.
# 927   856           Friedelsheim
# 928  8903      Gorxheimer Straße
# 929   910             Fußgönheim
# 930   940               Gönnheim
#
#                                                  stops lat lon
# 0    [{'id': '102301', 'lat': 49.38135, 'lon': 8.70...
# 1    [{'id': '103301', 'lat': 49.4179, 'lon': 8.759...
# 2    [{'id': '106201', 'lat': 49.412815, 'lon': 8.7...
# 3    [{'id': '106705', 'lat': 49.445717, 'lon': 8.6...
# 4    [{'id': '107901', 'lat': 49.412052, 'lon': 8.7...
# 5    [{'id': '108101', 'lat': 49.362934, 'lon': 8.6...
# 6    [{'id': '108401', 'lat': 49.410805, 'lon': 8.7...
# 7    [{'id': '108601', 'lat': 49.415085, 'lon': 8.7...
# 8    [{'id': '108801', 'lat': 49.41162, 'lon': 8.76...
# 9    [{'id': '109101', 'lat': 49.41345, 'lon': 8.77...
# 10   [{'id': '109301', 'lat': 49.414295, 'lon': 8.7...
# 11   [{'id': '109401', 'lat': 49.41506, 'lon': 8.73...
# 12   [{'id': '110201', 'lat': 49.4159, 'lon': 8.732...
# 13   [{'id': '110401', 'lat': 49.42635, 'lon': 8.75...
# 14   [{'id': '110602', 'lat': 49.423916, 'lon': 8.7...
# 15   [{'id': '110702', 'lat': 49.4226, 'lon': 8.756...
# 16   [{'id': '110801', 'lat': 49.42319, 'lon': 8.76...
# 17   [{'id': '110901', 'lat': 49.42257, 'lon': 8.76...
# 18   [{'id': '111601', 'lat': 49.42275, 'lon': 8.76...
# 19   [{'id': '111702', 'lat': 49.421135, 'lon': 8.7...
# 20   [{'id': '111901', 'lat': 49.41378, 'lon': 8.71...
# 21   [{'id': '112002', 'lat': 49.37202, 'lon': 8.70...
# 22   [{'id': '112101', 'lat': 49.378254, 'lon': 8.7...
# 23   [{'id': '112201', 'lat': 49.3704, 'lon': 8.705...
# 24   [{'id': '112301', 'lat': 49.376133, 'lon': 8.7...
# 25   [{'id': '112404', 'lat': 49.37408, 'lon': 8.70...
# 26   [{'id': '112501', 'lat': 49.37239, 'lon': 8.70...
# 27   [{'id': '112602', 'lat': 49.37283, 'lon': 8.70...
# 28   [{'id': '112701', 'lat': 49.359337, 'lon': 8.7...
# 29   [{'id': '112801', 'lat': 49.364086, 'lon': 8.7...
# ..                                                 ...  ..  ..
# 901  [{'id': '69538', 'lat': 49.40158, 'lon': 8.631...
# 902  [{'id': '695702', 'lat': 49.402145, 'lon': 8.6...
# 903  [{'id': '695903', 'lat': 49.38419, 'lon': 8.68...
# 904  [{'id': '69638', 'lat': 49.40001, 'lon': 8.626...
# 905  [{'id': '69735', 'lat': 49.401665, 'lon': 8.62...
# 906  [{'id': '707802', 'lat': 49.401527, 'lon': 8.6...
# 907  [{'id': '709735', 'lat': 49.40648, 'lon': 8.64...
# 908  [{'id': '713502', 'lat': 49.3955, 'lon': 8.709...
# 909  [{'id': '714012', 'lat': 49.509323, 'lon': 8.6...
# 910  [{'id': '730305', 'lat': 49.486786, 'lon': 8.4...
# 911  [{'id': '752006', 'lat': 49.478043, 'lon': 8.4...
# 912  [{'id': '752105', 'lat': 49.47389, 'lon': 8.45...
# 913  [{'id': '752205', 'lat': 49.47035, 'lon': 8.45...
# 914  [{'id': '752637', 'lat': 49.47656, 'lon': 8.45...
# 915  [{'id': '77105', 'lat': 49.53638, 'lon': 8.350...
# 916  [{'id': '77805', 'lat': 49.53737, 'lon': 8.3588}]
# 917  [{'id': '80606', 'lat': 49.53814, 'lon': 8.353...
# 918  [{'id': '812605', 'lat': 49.443253, 'lon': 8.5...
# 919  [{'id': '814301', 'lat': 49.47401, 'lon': 8.48...
# 920  [{'id': '815306', 'lat': 49.484493, 'lon': 8.3...
# 921  [{'id': '815406', 'lat': 49.47151, 'lon': 8.32...
# 922  [{'id': '82305', 'lat': 49.53692, 'lon': 8.355...
# 923  [{'id': '82902', 'lat': 49.41736, 'lon': 8.690...
# 924  [{'id': '850601', 'lat': 49.39546, 'lon': 8.64...
# 925  [{'id': '850915', 'lat': 49.452793, 'lon': 8.7...
# 926  [{'id': '851805', 'lat': 49.463356, 'lon': 8.4...
# 927  [{'id': '85602', 'lat': 49.45809, 'lon': 8.224...
# 928  [{'id': '890305', 'lat': 49.51757, 'lon': 8.54...
# 929  [{'id': '91002', 'lat': 49.466213, 'lon': 8.28...
# 930  [{'id': '94001', 'lat': 49.458214, 'lon': 8.23...
#
# [931 rows x 5 columns]

# %%
establishments['subtype'] = ""
tags = establishments.tags
types = establishments.type
type_df=establishments['type'].str[0:].str.split(':', expand=True)

# %%
type_df = type_df.drop([2],axis=1)
type_df = type_df.rename(columns={0:'type',1:'subtype'})
#unique_subtypes = type_df.subtype.unique() 
#unique_types = type_df.type.unique() 
establishments.type = type_df.type 
establishments.subtype = type_df.subtype

# %%
establishments[0:3]
amenities_subtypes = establishments[establishments.type == 'amenity'].subtype.unique()
amenities_subtypes = pd.DataFrame(amenities_subtypes)
amenities_subtypes.to_csv("amenity_subtypes.csv")

tourism_subtypes = establishments[establishments.type == 'tourism'].subtype.unique()
tourism_subtypes = pd.DataFrame(tourism_subtypes)
tourism_subtypes.to_csv("tourism_subtypes.csv")

leisure_subtypes = establishments[establishments.type == 'leisure'].subtype.unique()
leisure_subtypes = pd.DataFrame(leisure_subtypes)
leisure_subtypes.to_csv("leisure_subtypes.csv")

shop_subtypes = establishments[establishments.type == 'shop'].subtype.unique()
shop_subtypes = pd.DataFrame(shop_subtypes)
shop_subtypes.to_csv("shop_subtypes.csv")

# %%
types = establishments.type.unique()
amenities_subtypes = establishments[establishments.type == 'amenity'].subtype.unique()
subtypes = pd.DataFrame(subtypes)
subtypes.to_csv("unique_subtypes.csv")

# %%
def get_station_establishments(establishments,station_lat,station_lon,square_size = 0.0005):
    lat_low = station_lat - square_size
    lat_high = station_lat + square_size
    lon_low = station_lon - square_size
    lon_high = station_lon + square_size

    near_establishments = establishments[(establishments.lat<lat_high) &
                                         (establishments.lat>lat_low) &
                                         (establishments.lon<lon_high) &
                                         (establishments.lat>lon_low)]
    return near_establishments

station_stablishments=get_station_establishments(establishments,49.544802,8.670092,square_size=0.0002)

# %%
for ii in range(stations.shape[0]):
    stops1 = stations.stops[ii]
    stops1 = stops1[0]
    lat = stops1['lat']
    lon = stops1['lon']
    stations.lat[ii]=lat
    stations.lon[ii]=lon

# %%
stations_lat = stations['lat']
stations_lat.to_csv('stations_lat.csv')
stations_lat = stations_lat.values

establishments_lat = establishments['lat']
establishments_lat.to_csv('establishments_lat.csv')
establishments_lat = establishments_lat.values

stations_lon = stations['lon']
stations_lon.to_csv('stations_lon.csv')
stations_lon = stations_lon.values

establishments_lon = establishments['lon']
establishments_lon.to_csv('establishments_lon.csv')
establishments_lon = establishments_lon.values

# %%
lat_dist = np.subtract.outer(establishments_lat, stations_lat)
lon_dist = np.subtract.outer(establishments_lon, stations_lon)

# %%
#dist_matrix = np.sqrt([np.abs(lon_dist) + np.abs(lat_dist)])
dist_matrix = np.power([lon_dist**2 + lat_dist**2], 0.5 )
dist_matrix = np.squeeze(dist_matrix)
print(dist_matrix.shape)

closest_station = np.argmin( dist_matrix , 1)
print(closest_station.shape)
# Out:
# (39512, 931)
# (39512,)

# %%
np.savetxt("establishments_closest_station.csv", closest_station, delimiter=",")
